# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Installing Seaborn

# %%
#pip install seaborn

# %%
# Installing Seaborn
# Load Datasets To Construct Seaborn Plots
# Styling and Themes in Seaborn
# Seaborn Color Palette
# Seaborn’s plotting functions
# Plotting with the relplot function
# Histogram
# Bar Plot
# Count Plot
# Joint Plot
# Regplot
# Lm Plot
# KDE Plot
# Box Plot
# Violin Plot
# Heatmap
# Cluster map
# Facetgrid
# Pair Plot

# %% [markdown]
# # Load Datasets To Construct Seaborn Plots

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset('car_crashes')
df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %% [markdown]
# # Styling and Themes in Seaborn

# %%
plt.scatter(df.speeding,df.alcohol)
plt.show()

# %%
plt.scatter(df.speeding,df.alcohol)
sns.set_style('ticks')
plt.show()

# %%
plt.scatter(df.speeding,df.alcohol)
sns.set_style('whitegrid')
plt.show()

# %%
plt.scatter(df.speeding,df.alcohol)
sns.set_style('darkgrid')
plt.show()

# %%
plt.scatter(df.speeding,df.alcohol)
sns.set_style('dark')
plt.show()

# %%
plt.scatter(df.speeding,df.alcohol)
sns.set_style('dark')
sns.set_context('notebook')
plt.show()

# %%
plt.scatter(df.speeding,df.alcohol)
sns.set_style('dark')
sns.set_context('poster')
plt.show()

# %%
plt.scatter(df.speeding,df.alcohol)
sns.set_style('dark')
sns.set_context('paper')
plt.show()

# %%
plt.scatter(df.speeding,df.alcohol)
sns.set_style('dark')
sns.set_context('talk')
plt.show()

# %% [markdown]
# # Seaborn Color Palette

# %%
# 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 
#'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap',
# 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 
# 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 
#'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r',
#'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 
#'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 
#'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 
#'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu',
# 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r',
# 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 
#'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia',
# 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r',
 #'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 
#'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r',
 #'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis',
 #'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 
#'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 
#'flag_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 
#'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar',
# 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 
#'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r',
# 'gnuplot', 'gnuplot2','gnuplot2_r', 'gnuplot_r',
 #'gray', 'gray_r', 'hot', 'hot_r', 'hsv',
 #'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 
#'jet_r', 'magma', 'magma_r', 'mako', 'mako_r',

# %% [markdown]
# # Plotting with the relplot function

# %%
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(data=tips,x="total_bill",y="tip")

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="day")

# %%
sns.relplot(data=tips, x="total_bill", y="tip", hue="sex", col="day", col_wrap=2)

# %%
sns.relplot(data=tips,x="size",y="tip",kind="line",errorbar=None)

# %% [markdown]
# # Histogram

# %%
df = sns.load_dataset('iris')
sns.histplot(df['petal_length'],kde = False)
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %% [markdown]
# # Bar Plot

# %% [markdown]
# ## Vertical barplot

# %%
# load dataset
titanic = sns.load_dataset('titanic')
# create plot
sns.barplot(x = 'embark_town', y = 'age', data = titanic,
            palette = 'PuRd',errorbar=None 
            )

plt.show()

# %%
sns.barplot(x = 'sex', y = 'survived', hue = 'class', data = titanic,
            palette = 'PuRd',
            order = ['male', 'female'],  
            capsize = 0.05,             
            saturation = 8,             
            errcolor = 'gray', errwidth = 2,  
            errorbar = 'sd'  
            )

plt.show()

# %% [markdown]
# # Horizontal Barplot

# %%
sns.set_context('paper')
sns.barplot(x = 'age', y = 'embark_town', data = titanic,
            palette = 'PuRd', orient = 'h',
            )
plt.show()

# %% [markdown]
# # countplot

# %%
sns.countplot(x = 'class', hue = 'who', data = titanic, palette = 'magma')
plt.title('Survivors')
plt.show()

# %% [markdown]
# # Point Plot
# ## Point plot is used to show point estimates and confidence intervals using scatter plot glyphs. A point plot represents an estimate of central tendency for a numeric variable by the position of scatter plot points and provides some indication of the uncertainty around that estimate using error bars.

# %%
data = sns.load_dataset("tips") 
sns.pointplot(x="day", y="tip", data=data)
plt.show()

# %%
sns.pointplot(x="time", y="total_bill", hue="smoker",
                   data=data, palette="Accent")
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %% [markdown]
# # Joint Plot
# ## Joint Plot draws a plot of two variables with bivariate and univariate graphs. It uses the Scatter Plot and Histogram. Joint Plot can also display data using Kernel Density Estimate (KDE) and Hexagons.

# %%
sns.set_style("dark")
tips=sns.load_dataset('tips')
sns.jointplot(x='total_bill', y='tip',data=tips)

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='reg')

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='kde')

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex')

# %% [markdown]
# # Regplot
# ## Regplot is one of the functions in Seaborn that are used to visualize the linear relationship as determined through regression. Also, you‘ll see a slightly shaded portion around the regression line which indicates how much the pints are scattered around a certain area.

# %%
sns.regplot(x="total_bill", y="tip", data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.regplot(x="size", y="total_bill", data=tips, x_jitter=0.1)
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
sns.regplot(x="total_bill", y="tip", data=tips,ci=None)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Lm Plot

# %%
sns.lmplot(x="total_bill", y="tip", data=tips)

# %% [markdown]
# # Here is how we can use the advance features of lmplot() and use it with multi-plot grid for plotting conditional relationships.

# %%
sns.lmplot(x="total_bill", y="tip", col="day", hue="day", data=tips, col_wrap=2, height=3)

# %% [markdown]
# # KDE plot
# ## KDE plot is a Kernel Density Estimate that is used for visualizing the Probability Density of the continuous or non-parametric data variables

# %%
# Assuming you have loaded the "iris" dataset
iris = sns.load_dataset("iris")

# Plotting the KDE Plot
sns.kdeplot(iris.loc[iris['species'] == 'setosa', 'sepal_length'], color='b', fill=True, label='setosa')
sns.kdeplot(iris.loc[iris['species'] == 'virginica', 'sepal_length'], color='r', fill=True, label='virginica')

# Show the legend
plt.legend()

# Show the plot
plt.show()

# %%
# Setting up the samples
iris_setosa = iris.query("species=='setosa'")
iris_virginica = iris.query("species=='virginica'")

# Plotting the KDE Plot for sepal_length and sepal_width
sns.kdeplot(data=iris_setosa, x='sepal_length', y='sepal_width', cmap="Reds", fill=True, label='Iris Setosa', common_norm=False, thresh=0.05)
sns.kdeplot(data=iris_virginica, x='sepal_length', y='sepal_width', cmap="Blues", fill=True, label='Iris Virginica', common_norm=False, thresh=0.05)

# Set labels and title
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.title('KDE Plot for Sepal Length and Sepal Width')

# Show the legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Box Plot
# ## The box plot, also called the box and whisker diagram is used for depicting groups of numerical data through the quartiles.

# %% [markdown]
# # A box plot is composed of a summary of 5 different data points: the minimum, first quartile, median, third quartile, and maximum.
#
# ## 1.Minimum
# ## 2.First Quartile or 25%
# ## 3.Median (Second Quartile) or 50%
# ## 4.Third Quartile or 75%
# ## 5.Maximum

# %%
tips = sns.load_dataset("tips")
sns.boxplot(x="day", y="total_bill", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Violin Plot

# %%
sns.violinplot(x=tips["total_bill"])
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.violinplot(x="day", y="total_bill", hue="smoker",data=tips, palette="muted")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day", y="total_bill", hue="smoker",data=tips, palette="muted", split=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Heatmap
# ## A heatmap is a two-dimensional graphical representation of data where the individual values that are contained in a matrix are represented as colours.

# %%
flights=sns.load_dataset("flights")
print(flights)
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights = flights.pivot("month", "year", "passengers")
print(flights)
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
flights.corr()
# Out:
# year      1949      1950      1951      1952      1953      1954      1955  \
# year
# 1949  1.000000  0.949435  0.944994  0.905623  0.970144  0.911553  0.908190
# 1950  0.949435  1.000000  0.946923  0.957062  0.880477  0.930967  0.949866
# 1951  0.944994  0.946923  1.000000  0.923131  0.939609  0.959165  0.939515
# 1952  0.905623  0.957062  0.923131  1.000000  0.861005  0.942879  0.956044
# 1953  0.970144  0.880477  0.939609  0.861005  1.000000  0.913945  0.884986
# 1954  0.911553  0.930967  0.959165  0.942879  0.913945  1.000000  0.989433
# 1955  0.908190  0.949866  0.939515  0.956044  0.884986  0.989433  1.000000
# 1956  0.940419  0.938707  0.946961  0.960854  0.929524  0.984947  0.985527
# 1957  0.933350  0.934320  0.946232  0.963146  0.928578  0.986983  0.982708
# 1958  0.912513  0.904400  0.911054  0.960107  0.907120  0.962541  0.961328
# 1959  0.901456  0.927191  0.947280  0.962860  0.902622  0.988882  0.984109
# ...

# %%
sns.heatmap(flights)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
car=sns.load_dataset("car_crashes")
car
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
car.corr()
# Out:
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# speeding          -0.077675   -0.065928
# alcohol           -0.170612   -0.112547
# not_distracted    -0.174856   -0.075970
# no_previous       -0.156895   -0.006359
# ins_premium        1.000000    0.623116
# ins_losses         0.623116    1.000000

# %%
sns.heatmap(corr,annot=True,linewidths=.5,cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# # Cluster map
# ## Cluster map method plots a matrix dataset as a hierarchically-clustered heatmap. It uses hierarchical clusters to order data by similarity

# %%
flights=sns.load_dataset("flights")
flights = flights.pivot("month", "year", "passengers")
sns.clustermap(flights,linewidths=.5,cmap="coolwarm")

# %%
flights=sns.load_dataset("flights")
flights = flights.pivot("month", "year", "passengers")
sns.clustermap(flights,linewidths=.5,cmap="coolwarm",col_cluster=False)

# %% [markdown]
# # Facetgrid
# ## Facet grid forms a matrix of panels defined by row and column by dividing the variables. Due to panels, a single plot looks like multiple plots. It is very helpful to analyze all combinations in two discrete variables.

# %%
tips = sns.load_dataset("tips")
g = sns.FacetGrid(tips, col="time")
g.map(sns.scatterplot, "total_bill", "tip")

# %%
tips = sns.load_dataset("tips")
g = sns.FacetGrid(tips, col="time", row="sex")
g.map(sns.scatterplot, "total_bill", "tip")

# %% [markdown]
# # Pair Plot
# ## Pair plot creates a grid of Axes such that each numeric variable in data will be shared across the y-axes across a single row and the x-axes across a single column. The diagonal plots are treated differently: a univariate distribution plot is drawn to show the mar

# %%
df = sns.load_dataset('iris')
sns.set_style("ticks")
sns.pairplot(df,hue = 'species',diag_kind = "kde",kind = "scatter",palette = "husl")
plt.show()
